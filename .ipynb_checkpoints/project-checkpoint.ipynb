# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab 

from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

#read csv into dataframe
GOPSentiDf = pd.read_csv('2016GOPPresDebSenti.csv')
AirlineSentiDf = pd.read_csv('TweetsUSAirlineSenti.csv')

#Begin feature removal
GOPSentiDf.count()
# Out:
# id                           13871
# candidate                    13775
# candidate_confidence         13871
# relevant_yn                  13871
# relevant_yn_confidence       13871
# sentiment                    13871
# sentiment_confidence         13871
# subject_matter               13545
# subject_matter_confidence    13871
# candidate_gold                  28
# name                         13871
# relevant_yn_gold                32
# retweet_count                13871
# sentiment_gold                  15
# subject_matter_gold             18
# text                         13871
# tweet_coord                     21
# tweet_created                13871
# tweet_id                     13871
# tweet_location                9959
# user_timezone                 9468
# dtype: int64

# %%
AirlineSentiDf.count()
# Out:
# tweet_id                        14640
# airline_sentiment               14640
# airline_sentiment_confidence    14640
# negativereason                   9178
# negativereason_confidence       10522
# airline                         14640
# airline_sentiment_gold             40
# name                            14640
# negativereason_gold                32
# retweet_count                   14640
# text                            14640
# tweet_coord                      1019
# tweet_created                   14640
# tweet_location                   9907
# user_timezone                    9820
# dtype: int64

# %%
#we want the sentiment analysis to be as general as possible, independent of user location, when they tweeted, 
#the tweet's subject matter, how often their tweets get retweeted, who is the user, 

GOPSentiDf.drop('user_timezone', 1, inplace = True)
GOPSentiDf.drop('tweet_location', 1, inplace = True)
GOPSentiDf.drop('tweet_id', 1, inplace = True)
GOPSentiDf.drop('tweet_created', 1, inplace = True)
GOPSentiDf.drop('tweet_coord', 1, inplace = True)
#subject matter gold is the specific topic of tweeted text, such as Religion, Abortion, Immigration, FOX news, etc.
GOPSentiDf.drop('subject_matter_gold', 1, inplace = True)
#sentiment gold is repetitive of the sentiment column
GOPSentiDf.drop('sentiment_gold', 1, inplace = True)
GOPSentiDf.drop('retweet_count', 1, inplace = True)
#relevant_yn_gold is repetitive of relevant
GOPSentiDf.drop('relevant_yn_gold', 1, inplace = True)
GOPSentiDf.drop('name', 1, inplace = True)
#candidate_gold is repetitive of candidate
GOPSentiDf.drop('candidate_gold', 1, inplace = True)
GOPSentiDf.drop('subject_matter_confidence', 1, inplace = True)
GOPSentiDf.drop('subject_matter', 1, inplace = True)
GOPSentiDf.drop('relevant_yn_confidence', 1, inplace = True)
GOPSentiDf.drop('relevant_yn', 1, inplace = True)
GOPSentiDf.drop('candidate_confidence', 1, inplace = True)
GOPSentiDf.drop('candidate', 1, inplace = True)

#we want to do the same for the tweets for the US Airlines
AirlineSentiDf.drop('user_timezone', 1, inplace = True)
AirlineSentiDf.drop('tweet_location', 1, inplace = True)
AirlineSentiDf.drop('tweet_created', 1, inplace = True)
AirlineSentiDf.drop('tweet_coord', 1, inplace = True)
AirlineSentiDf.drop('retweet_count', 1, inplace = True)
AirlineSentiDf.drop('negativereason_gold', 1, inplace = True)
AirlineSentiDf.drop('name', 1, inplace = True)
AirlineSentiDf.drop('airline_sentiment_gold', 1, inplace = True)
AirlineSentiDf.drop('airline', 1, inplace = True)
AirlineSentiDf.drop('negativereason_confidence', 1, inplace = True)
AirlineSentiDf.drop('negativereason', 1, inplace = True)

# %%
GOPSentiDf.count()
# Out:
# id                      13871
# sentiment               13871
# sentiment_confidence    13871
# text                    13871
# dtype: int64

# %%
AirlineSentiDf.count()
# Out:
# tweet_id                        14640
# airline_sentiment               14640
# airline_sentiment_confidence    14640
# text                            14640
# dtype: int64

# %%
#list of emotions, not emojis
#create 2d array with 50 columns and 3 rows, where the row determines the number of character per emoji
#i.e., :) contains 2 characters so it belongs it row 0, while :-D goes to row 1, and so on
PosEmoAr = [[':)', ':]', ':}', '=)', '=]', '=}', ':B', '=B', '<3', '^^', ':*', '=*', ';)', ';]', 
             ';}', '=P', '=p', ':P', ':p', ':b', '=b'], 
            [':o)', ':o]', ':o}', ':-]', ':-)', ':-}', '=^]', '=^)', '=^}', ':-D', ':-B', 
             ':^D', ':^B', '=^B', '=^D', ':\')', ':\']', '=\'}', '^.^', '^-^', '^_^', ':-*', 
             ':-p', ':-P', ':-b', ':^p', ':^P', ':^b', '\\o\\', '/o/', '=^p', '=^P', '=^b', '\\o/']]
NegEmoAr = [['D:', 'D=', ':(', ':[', ':{', '=(', '=[', '={', '=\\', ':\\', '=/', ':/', '=$', 'Oo'], 
            ['D-:', 'D^:', 'D^=', ':o(', ':o[', ':^(', ':^[', ':^{', '=^(', '=^{', '>=(', '>=[', '>={', 
             ':-[', ':-(', '=^[', '>=[', ':\'(', ':\'[', ':\'{', '=\'{', '=\'(', '=\'[', 'o.O', 'O_o', ':o{'],
            ['>:-{', '>:-[', '>:-(', '>=^[', '>=^(', '>:-{', '>=^{'],
            ['>:-=(', ':$:-{']]
NeuEmoAr = [[':|', '=|', '><', ':o', ':O', '=0', ':@', '=@', ':x', '=X', ':#', '=#'], 
            [':-|', '>.<', '>_<', ':^o', ':^@', '-.-', '-_-', ':-x', ':-X', ':-@', ':-#', ':^x', ':^#'], 
            ['-.-\'', '-_-\'']]

# %%
#create features: number of negative and positive words and emoticons, number of emoticons
GOPTxtAr = GOPSentiDf.values[0:,][:,3]
GOPNumPosAr = []
GOPNumNegAr = []
GOPNumEmoAr = []
for i in range(len(GOPTxtAr)):
    GOPNumPosAr.append(0)
    GOPNumNegAr.append(0)
    GOPNumEmoAr.append(0)
    
AirTxtAr = AirlineSentiDf.values[0:,][:,3]
AirNumPosAr = []
AirNumNegAr = []
AirNumEmoAr = []

for i in range(len(AirTxtAr)):
    AirNumPosAr.append(0)
    AirNumNegAr.append(0)
    AirNumEmoAr.append(0)
    
index = 0
for text in GOPTxtAr:
    #remove indefinite and definite articles
    GOPTxtAr[index] = str(GOPTxtAr[index]).replace('The ', '')
    GOPTxtAr[index] = str(GOPTxtAr[index]).replace('the ', '')
    GOPTxtAr[index] = str(GOPTxtAr[index]).replace('An ', '')
    GOPTxtAr[index] = str(GOPTxtAr[index]).replace('an ', '')
    GOPTxtAr[index] = str(GOPTxtAr[index]).replace('A ', '')
    GOPTxtAr[index] = str(GOPTxtAr[index]).replace('a ', '')
    GOPTxtAr[index] = str(GOPTxtAr[index]).replace('RT ', '')
    index += 1

index = 0
for text in AirTxtAr:
    AirTxtAr[index] = str(AirTxtAr[index]).replace('The ', '')
    AirTxtAr[index] = str(AirTxtAr[index]).replace('the ', '')
    AirTxtAr[index] = str(AirTxtAr[index]).replace('An ', '')
    AirTxtAr[index] = str(AirTxtAr[index]).replace('an ', '')
    AirTxtAr[index] = str(AirTxtAr[index]).replace('A ', '')
    AirTxtAr[index] = str(AirTxtAr[index]).replace('a ', '')
    AirTxtAr[index] = str(AirTxtAr[index]).replace('RT ', '')
    index += 1

# %%
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize.moses import MosesDetokenizer

updatedGOP = []
z = 0
for text in GOPTxtAr:
    ex_s = GOPTxtAr[z]
    words = word_tokenize(ex_s)
    sw = set(stopwords.words("english"))
    filtered_sentence = []

    for w in words:
        if w not in sw:
            filtered_sentence.append(w)

    y = len(filtered_sentence)
    for x in range(0,y):
        if filtered_sentence[x] == '#': 
            filtered_sentence[x] = ' '
            if x < len(filtered_sentence)-2: #make sure the index is not out of bound
                filtered_sentence[x+1] = ' '
        if filtered_sentence[x] == 'https':
            filtered_sentence[x] = ' '
            if x < len(filtered_sentence)-1:
            filtered_sentence[x+1]= ' '
            filtered_sentence[x+2] = ' '  
        if filtered_sentence[x] == 'http':
            filtered_sentence[x] = ' '
            if x < len(filtered_sentence)-1:
            filtered_sentence[x+1]= ' '
            filtered_sentence[x+2] = ' '  
        if filtered_sentence[x] == '#': 
            filtered_sentence[x] = ' '
            if x < len(filtered_sentence)-2: #make sure the index is not out of bound
                filtered_sentence[x+1] = ' '
        y += 1
    #print(filtered_sentence)
    detokenizer = MosesDetokenizer()
    updatedGOP.append(detokenizer.detokenize(filtered_sentence, return_str=True))
    z += 1
print(updatedGOP[1])
# Out:
#   File "<ipython-input-41-92f3a2a32662>", line 26
#     filtered_sentence[x+1]= ' '
#                     ^
# IndentationError: expected an indented block

# %%
updatedAir = []
z = 0
for text in AirTxtAr:
    ex_s = AirTxtAr[z]
    words = word_tokenize(ex_s)
    sw = set(stopwords.words("english"))
    filtered_sentence = []

    for w in words:
        if w not in sw:
            filtered_sentence.append(w)
    
    y = len(filtered_sentence)
    for x in range(0,y):
        if filtered_sentence[x] == '#': 
            filtered_sentence[x] = ' '
            if x < len(filtered_sentence)-2:
                filtered_sentence[x+1] = ' '
        if filtered_sentence[x] == 'https':
            filtered_sentence[x] = ' '
            if x < len(filtered_sentence)-1:
                filtered_sentence[x+1]= ' '
                filtered_sentence[x+2] = ' '  
        if filtered_sentence[x] == 'http':
            filtered_sentence[x] = ' '
            if x < len(filtered_sentence)-1:
                filtered_sentence[x+1]= ' '
                filtered_sentence[x+2] = ' '  
        y += 1
    #print(filtered_sentence)
    detokenizer = MosesDetokenizer()
    updatedAir.append(detokenizer.detokenize(filtered_sentence, return_str=True))
    z += 1
print(updatedAir)
# Out:
# ['@ VirginAmericWhat @ dhepburn said.', "@ VirginAmericplus've added commercials experience... tacky.", "@ VirginAmericI n't today... Must meI need take another trip!", "@ VirginAmericit's really aggressive blast obnoxious ``entertainment ''guests' faces & amp; little recourse", "@ VirginAmericand's really big bad thing", "@ VirginAmericseriously would pay $30 flight seats n't playing.'s really bad thing flying VA", '@ VirginAmericyes, nearly every time I fly VX “ear worm ” ’ go away:)', '@ VirginAmericReally missed prime opportunity Men Without Hats parody,.', "@ virginamericWell, I didn't…but NOW I DO!: -D", "@ VirginAmericit amazing, arrived hour early. You're good.", '@ VirginAmericdid know suicide second leading cause death among teens 10-24', '@ VirginAmericI & lt; 3 pretty graphics. much better thminimal iconography.: D', "@ VirginAmericThis great deal! Already thinking 2nd trip @ Australi & amp; I n't even gone 1st trip yet!; p", "@ VirginAmeric @ virginmediI'm flying skies! U take away travel", '@ VirginAmericThanks!', '@ VirginAmericSFO-PDX schedule still MIA.', "@ VirginAmericSo excited first cross country flight LAX MCO I've heard nothing great things Virgin America. 29DaysToGo", "@ VirginAmeric I flew NYC SFO last week could n't fully sit seat due two large gentlemon either side. HELP!", 'I ❤️ flying @ VirginAmerica. ☺️👍', '@ VirginAmericyou know would amazingly awesome? BOS-FLL PLEASE!!!!!!! I want fly.', '@ VirginAmericwhy first fares May three times thother carriers seats available select???', '@ VirginAmericI love graphic.', '@ VirginAmericI love hipster innovation. You feel good brand.', '@ VirginAmericwill making BOS & gt; LAS non stop permanently anytime soon?', '@ VirginAmericyou guys messed seating.. I reserved seating friends guys gave seat away... 😡 I want free internet', "@ VirginAmericstatus match program. I applied's three weeks. Called emailed response.", "@ VirginAmericWhat happened 2 ur vegfood options?! At least say ur site know I wo n't able 2 eat anything next 6 hrs fail", "@ VirginAmericdo miss? Do n't worry'll together soon.", "@ VirginAmericamazing ca n't get cold air vents. SFOtoBOS", '@ VirginAmericLAX EWR - Middle seat red eye. Such noob maneuver. andchexmix', "@ VirginAmerichi! I bked cool birthday trip, ca n't add elevate. cause entered middle name Flight Booking Problems 😢", '@ VirginAmericAre hours operation Club SFO posted online current?', '@ VirginAmerichelp, left expensive headphones flight 89 IAD LAX today. Seat 2A. No one answering L & amp; F number LAX!', '@ VirginAmericawaiting return phone call, would prefer use online self-service option: (', '@ VirginAmericthis great news! Americcould start flights Hawaii end year vi @ Pacificbiznews', 'Nice @ VirginAmerica: Vibe moodlight takeoff touchdown.', '@ VirginAmericMoodlighting way fly! Best experience EVER! Cool calming. 💜✈ MoodlitMonday', '@ VirginAmeric @ freddieawards Done done! Best airline around, hands!', '@ VirginAmericwhen cI book flight Hawaii??', '@ VirginAmericYour chat support working site:', '@ VirginAmericView downtown Los Angeles, Hollywood Sign, beyond rain mountains!', "@ VirginAmericHey, first time flyer next week - excited! But I'm hard time getting flights added Elevate account. Help?", '@ VirginAmericplz help win bid upgrade flight 2/27 LAX -- - & gt; SEA!!! 🍷👍💺✈️', "@ VirginAmericI unused ticket moved new city n't fly. How cI fly expires? travelhelp", '@ VirginAmericare flights leaving Dallas Seattle time Feb 24?', "@ VirginAmericI'm good reason: rock!!", '@ VirginAmeric DREAM', '@ VirginAmericwow blew mind', '@ VirginAmeric @ ladygag @ carrieunderwood After last night @ ladygaga! I think @ carrieunderwood agree', '@ VirginAmeric @ ladygag @ carrieunderwood All entertaining', "@ VirginAmericIs flight 769's way? Was supposed take 30 minutes ago. Website still shows ``On Time ''`` In Flight''. Thanks.", '@ VirginAmeric @ ladygag @ carrieunderwood Julie Andrews way though @ ladygagwas impressive! NO @ Carrieund ...
